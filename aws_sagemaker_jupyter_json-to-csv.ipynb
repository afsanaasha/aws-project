# %%
# Import required libraries
import pandas as pd
import json

# %%
# Loading the json data and saving it as python object
file = []
for line in open('Magazine_Subscriptions.json', 'r'):
    file.append(json.loads(line))
    
file
# Out:
# [{'overall': 5.0,
#   'vote': '9',
#   'verified': False,
#   'reviewTime': '11 8, 2001',
#   'reviewerID': 'AH2IFH762VY5U',
#   'asin': 'B00005N7P0',
#   'reviewerName': 'ted sedlmayr',
# ...

# %%
# Checking the object type
type(file)
# Out:
# list

# %%
# Converting list to pandas dataframe
df = pd.DataFrame(file)

# %%
# Inspecting the data
df
# Out:
#        overall vote  verified   reviewTime      reviewerID        asin  \
# 0          5.0    9     False   11 8, 2001   AH2IFH762VY5U  B00005N7P0
# 1          5.0    9     False  10 31, 2001   AOSFI0JEYU4XM  B00005N7P0
# 2          3.0   14     False  03 24, 2007  A3JPFWKS83R49V  B00005N7OJ
# 3          5.0   13     False  11 10, 2006  A19FKU6JZQ2ECJ  B00005N7OJ
# 4          5.0  NaN      True  07 14, 2014  A25MDGOMZ2GALN  B00005N7P0
# ...        ...  ...       ...          ...             ...         ...
# 89684      5.0  NaN      True  08 16, 2016   AB5HCI50SF1TK  B01HI8V1C2
# 89685      1.0  NaN      True  08 10, 2016  A2X11NZMPI7M0T  B01HI8V1C2
# 89686      5.0  NaN      True  07 31, 2016  A3EGFFBRQVO7L7  B01HI8V1C2
# 89687      5.0  NaN      True   10 5, 2017  A3H23AVKFN62ZT  B01HIZSSQM
# 89688      5.0  NaN      True  04 28, 2017  A1N6M7HRWMDE3D  B01HIZSSQM
#
#              reviewerName                                         reviewText  \
# ...

# %%
# Checking the type before writing it to csv
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Saving pandas dataframe as csv file
df.to_csv('C:/Users/mahab/Downloads/Magazine_Subscriptions.csv', index = False)
